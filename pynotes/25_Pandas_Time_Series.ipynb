# %% [markdown]
# # DataScience Course $\circ$ Pandas $\circ$ Time Series Data
# By Dr Boontawee Suntisrivaraporn
# <img src="https://1.bp.blogspot.com/-J1gxIX6Cp9w/Wy-lUTT-LqI/AAAAAAADIss/i8oWgsmB9OY8nRMc21XH_BA7AUCGkuGFgCLcBGAs/s1600/logo2.jpg" width=600>
# <hr>

# %% [markdown]
# ### Topics
# - Dates and times in Python
#     - `datetime`
#     - `dateutil`
# - Numpy
#     - `datetime64()`
#     - `timedelta64()`
# - Pandas's time series
#     - `to_datetime()`
#     - `date_range()`
#     - `period_range()`
#     - `timedelta_range()`
#
# - Indexing dataframe by time
#     - Recap dataframe's index, setting index
#     - `resample()` (aggregation)
#     - `asfreq()` (selection)
#     - `shift()`, `tshift()`
#     - `rolling()` (aggregation)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
#from pandas_datareader import data
#goog = data.DataReader("GOOG", start="2009", end="2016", data_source="google")

goog = pd.read_csv("../data/GOOG.csv")

# %% [markdown]
# ## $\Rightarrow$ Walk-through coding
# Pay attention to the class and then code through, step by step

# %%
# Out:
# datetime.datetime(2018, 7, 7, 0, 0)

# %%
# Out:
# datetime.datetime(2018, 7, 7, 0, 0)

# %% [markdown]
# ### Numpy `datetime64`

# %%
# Out:
# numpy.datetime64('2018-07-01')

# %% [markdown]
# ### Pandas `Timestamp`

# %%
# Out:
# Timestamp('2018-07-07 00:00:00')

# %% [markdown]
# `pd.date_range()`

# %% [markdown]
# ### Indexing by time series

# %% [markdown]
# ### Shifting and Rollling
#
# Optional

# %% [markdown]
# <hr>
# ## Finished!
