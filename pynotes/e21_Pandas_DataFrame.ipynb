# %% [markdown]
# # DataScience Course $\circ$ Pandas $\circ$ Series & DataFrame
# By Dr Boontawee Suntisrivaraporn
# <img src="https://1.bp.blogspot.com/-J1gxIX6Cp9w/Wy-lUTT-LqI/AAAAAAADIss/i8oWgsmB9OY8nRMc21XH_BA7AUCGkuGFgCLcBGAs/s1600/logo2.jpg" width=600>
# <hr>

# %% [markdown]
# ### Topics
# - pd.Series
# - pd.DataFrame
#     - create dataframe
#     - dataframe from file
#     - dataframe to file
# - indexing, slicing
# - `loc[]` and `iloc[]`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Exercises
# - Run provided codes prior to the exercise question
# - Add a **new cell** to try your code
# - Type in Python code in the box to get the results as displayed right below
#
# __Warning__: results will be replaced, so make sure you add a new cell to try your code

# %% [markdown]
# **$\Rightarrow$
# Create a pandas `Series` of 10 random values with labels from the following list:
# **
# ```python
# labels = list("abcdefghij")
# ```

# %%
# Out:
# a    0.568787
# b   -0.554344
# c    1.462244
# d   -0.707751
# e   -0.499213
# f   -0.352801
# g    1.803697
# h    0.875630
# i    0.497755
# j    0.764332
# dtype: float64

# %% [markdown]
# **$\Rightarrow$
# Use the function `pd.read_csv` to read 1000 rows of data from file `"../data/GlobalLandTemperaturesByCountry.csv.zip"`, and assign the obtained DataFrame object to variable `df`
# **
#
# Hint: if needed, use the magic command (`?`) or `<SHIFT>+<TAB>` to access the function doc

# %% [markdown]
# **$\Rightarrow$
# Check out the `shape` and `columns` of the dataframe `df`
# **

# %%
#shape
# Out:
# (10000, 4)

# %%
#columns
# Out:
# Index(['dt', 'AverageTemperature', 'AverageTemperatureUncertainty', 'Country'], dtype='object')

# %% [markdown]
# **$\Rightarrow$
# Access the data records for `Country=="Thailand"` and `dt=="2013-08-01"`
# **

# %%
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty Country
# 7308  2013-08-01              25.911                          0.331  Africa

# %% [markdown]
# **$\Rightarrow$
# Compute the average temperature
# **

# %%
# Out:
# 12.741002970398483

# %% [markdown]
# **$\Rightarrow$
# Slice the dataframe to see the rows indexed from 5000 to 5004, inclusively
# **

# %%
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty  \
# 5000  1985-01-01               1.224                          0.687
# 5001  1985-02-01               5.958                          0.284
# 5002  1985-03-01               8.859                          0.718
# 5003  1985-04-01              15.935                          0.218
# 5004  1985-05-01              20.540                          0.681
#
#           Country
# 5000  Afghanistan
# 5001  Afghanistan
# 5002  Afghanistan
# 5003  Afghanistan
# 5004  Afghanistan

# %% [markdown]
# **$\Rightarrow$
# Slice the dataframe to see the rows indexed from 5000 to 5004, inclusively, and only the first two columns
# **

# %%
# Out:
#               dt  AverageTemperature
# 5000  1985-01-01               1.224
# 5001  1985-02-01               5.958
# 5002  1985-03-01               8.859
# 5003  1985-04-01              15.935
# 5004  1985-05-01              20.540

# %% [markdown]
# **$\Rightarrow$
# Select records newer than 2010 (i.e. `dt > "2010-12-01"`). How many records are there?
# **

# %%
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty Country
# 3206  2011-01-01              -1.959                          0.461   Åland
# 3207  2011-02-01              -6.390                          0.454   Åland
# 3208  2011-03-01              -0.311                          0.249   Åland
# 3209  2011-04-01               4.804                          0.716   Åland
# 3210  2011-05-01               8.603                          0.457   Åland
# 3211  2011-06-01              14.473                          0.327   Åland
# 3212  2011-07-01              18.003                          0.581   Åland
# 3213  2011-08-01              16.819                          0.199   Åland
# 3214  2011-09-01              13.606                          0.201   Åland
# 3215  2011-10-01               8.583                          0.247   Åland
# 3216  2011-11-01               6.415                          0.438   Åland
# ...

# %% [markdown]
# ** OPTIONAL $\Rightarrow$
# Read again the whole dataset and select only the temperature data of Thailand. Then, export it in Excel under file name `"GlobalLandTemperatures_Thailand.xlsx"`
# **

# %% [markdown]
# <hr>
# ## Finished !
