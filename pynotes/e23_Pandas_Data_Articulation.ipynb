# %% [markdown]
# # DataScience Course $\circ$ Pandas $\circ$ Data Articulation
# By Dr Boontawee Suntisrivaraporn
# <img src="https://1.bp.blogspot.com/-J1gxIX6Cp9w/Wy-lUTT-LqI/AAAAAAADIss/i8oWgsmB9OY8nRMc21XH_BA7AUCGkuGFgCLcBGAs/s1600/logo2.jpg" width=600>
# <hr>

# %% [markdown]
# ### Topics
# - data exploration
#     - `head()`, `tail()`, `shape`, `columns`, `index`
#     - `count()`, `nunique()`, `unique()`, `value_counts()`
# - GroupBy
#     - `aggregate()`
#     - `filter()`
#     - `transform()`
#     - `apply()`
#     - `pivot_table`
# - `pd.get_dummies()`
# - `merge()` and `pd.concat()`

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

df = sns.load_dataset("planets")

# %% [markdown]
# ## Exercises
# - Run provided codes prior to the exercise question
# - Add a **new cell** to try your code
# - Type in Python code in the box to get the results as displayed right below
#
# __Warning__: results will be replaced, so make sure you add a new cell to try your code

# %% [markdown]
# **$\Rightarrow$
# Use `head()` and `tail()` methods to view the first two records and the last three records
# **
#
# Optional: use `pd.concat()` to combine the two views together into a single dataframe

# %%
# Out:
#             method  number  orbital_period  mass  distance  year
# 0  Radial Velocity       1         269.300  7.10     77.40  2006
# 1  Radial Velocity       1         874.774  2.21     56.95  2008

# %%
# Out:
#        method  number  orbital_period  mass  distance  year
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
# Out:
#                method  number  orbital_period  mass  distance  year
# 0     Radial Velocity       1      269.300000  7.10     77.40  2006
# 1     Radial Velocity       1      874.774000  2.21     56.95  2008
# 1032          Transit       1        3.191524   NaN    174.00  2007
# 1033          Transit       1        4.125083   NaN    293.00  2008
# 1034          Transit       1        4.187757   NaN    260.00  2008

# %% [markdown]
# **$\Rightarrow$
# Find out how many unique "method"s are there using `nunique()`
# **

# %%
# Out:
# 10

# %% [markdown]
# **$\Rightarrow$
# Use the dataframe's `describe()` method to quickly view statistics of the data
# **
#
# Can one says anything about "year" ?

# %%
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %% [markdown]
# **$\Rightarrow$
# Use `groupby` to see the median "mass" of the planets discovered in each "year"
# **

# %%
# Out:
# year
# 1989     40.570
# 1992        NaN
# 1994        NaN
# 1995     15.360
# 1996     14.840
# 1997     17.430
# 1998     21.290
# 1999     29.760
# 2000     32.865
# 2001     33.650
# 2002     37.440
# 2003     35.955
# 2004     48.950
# 2005     35.870
# 2006     46.940
# 2007     80.580
# 2008     56.070
# 2009     52.830
# 2010     90.000
# 2011     87.870
# 2012    200.000
# 2013    132.000
# 2014    272.000
# Name: distance, dtype: float64

# %%
# optional

# %% [markdown]
# **$\Rightarrow$
# Use `groupby()` and `aggregate()` to see the following summaries for each discovering "method"
# **
# - `min` and `max` of the "orbital_period"
# - `median` of the "mass"
# - `min` of the "year" started using

# %%
# Out:
#                               orbital_period                  mass  year
#                                          min            max median   min
# method
# Astrometry                        246.360000    1016.000000    NaN  2010
# Eclipse Timing Variations        1916.250000   10220.000000  5.125  2008
# Imaging                          4639.150000  730000.000000    NaN  2004
# Microlensing                     1825.000000    5100.000000    NaN  2004
# Orbital Brightness Modulation       0.240104       1.544929    NaN  2011
# Pulsar Timing                       0.090706   36525.000000    NaN  1992
# Pulsation Timing Variations      1170.000000    1170.000000    NaN  2007
# Radial Velocity                     0.736540   17337.500000  1.260  1989
# Transit                             0.355000     331.600590  1.470  2002
# Transit Timing Variations          22.339500     160.000000    NaN  2011

# %% [markdown]
# **$\Rightarrow$
# Use `groupby()` to group by two variables: "year" and "method" to see the average (i.e. `mean()`) of the distance
# **

# %%
# Out:
# method  Astrometry  Eclipse Timing Variations  Imaging  Microlensing  \
# year
# 1989           NaN                        NaN      NaN           NaN
# 1992           NaN                        NaN      NaN           NaN
# 1994           NaN                        NaN      NaN           NaN
# 1995           NaN                        NaN      NaN           NaN
# 1996           NaN                        NaN      NaN           NaN
# 1997           NaN                        NaN      NaN           NaN
# 1998           NaN                        NaN      NaN           NaN
# 1999           NaN                        NaN      NaN           NaN
# 2000           NaN                        NaN      NaN           NaN
# 2001           NaN                        NaN      NaN           NaN
# 2002           NaN                        NaN      NaN           NaN
# 2003           NaN                        NaN      NaN           NaN
# ...

# %% [markdown]
# **$\Rightarrow$
# Use `pivot_table()` method to do the same as above
# **

# %%
# Out:
# method  Astrometry  Eclipse Timing Variations  Imaging  Microlensing  \
# year
# 1989           NaN                        NaN      NaN           NaN
# 1992           NaN                        NaN      NaN           NaN
# 1994           NaN                        NaN      NaN           NaN
# 1995           NaN                        NaN      NaN           NaN
# 1996           NaN                        NaN      NaN           NaN
# 1997           NaN                        NaN      NaN           NaN
# 1998           NaN                        NaN      NaN           NaN
# 1999           NaN                        NaN      NaN           NaN
# 2000           NaN                        NaN      NaN           NaN
# 2001           NaN                        NaN      NaN           NaN
# 2002           NaN                        NaN      NaN           NaN
# 2003           NaN                        NaN      NaN           NaN
# ...

# %% [markdown]
# **$\Rightarrow$
# Use funciton `get_dummies` to make a one-hot encoding of the variable "method"
# **
#
# Optional: rename the column names to be lower case, replace space by "\_", and add the prefix "method_"

# %%
# Out:
#       method_astrometry  method_eclipse_timing_variations  method_imaging  \
# 0                     0                                 0               0
# 1                     0                                 0               0
# 2                     0                                 0               0
# 3                     0                                 0               0
# 4                     0                                 0               0
# 5                     0                                 0               0
# 6                     0                                 0               0
# 7                     0                                 0               0
# 8                     0                                 0               0
# 9                     0                                 0               0
# 10                    0                                 0               0
# 11                    0                                 0               0
# ...

# %% [markdown]
# <hr>
# ## Finished!
