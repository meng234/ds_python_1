# %% [markdown]
# # DataScience Course $\circ$ Pandas $\circ$ Series & Missing Data
# By Dr Boontawee Suntisrivaraporn
# <img src="https://1.bp.blogspot.com/-J1gxIX6Cp9w/Wy-lUTT-LqI/AAAAAAADIss/i8oWgsmB9OY8nRMc21XH_BA7AUCGkuGFgCLcBGAs/s1600/logo2.jpg" width=600>
# <hr>

# %% [markdown]
# ### Topics
# - missing data
# - `null`, `NaN`, `NA`
# - `isnull()`, `notnull()`
# - `dropna()`, `fillna()`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

temp = pd.read_csv("../data/GlobalLandTemperaturesByCountry.csv.zip")
temp = temp[temp['Country']=="Thailand"][:500]

def plot_temp(temp_):
    temp_.set_index('dt')['AverageTemperature'].plot(style="--", figsize=(15,4)) ;
    temp.set_index('dt')['AverageTemperature'].plot(color="g", figsize=(15,4)) ;

rs = np.random.RandomState(3)
mt = rs.randint(0, 100, 25).reshape(5, 5)
df = pd.DataFrame(mt, columns=list("uvxyz"), index=list("abcde"))
for i in range(8):
    df.iloc[rs.randint(0, 5), rs.randint(0, 5)] = np.nan
    
df
# Out:
#       u     v     x   y   z
# a  24.0   NaN  56.0  72   0
# b  21.0  19.0  74.0  41  10
# c   NaN  38.0  96.0  20  44
# d   NaN   NaN   NaN  26  81
# e  90.0   NaN  66.0   2  63

# %% [markdown]
# ## Exercises
# - Run provided codes prior to the exercise question
# - Add a **new cell** to try your code
# - Type in Python code in the box to get the results as displayed right below
#
# __Warning__: results will be replaced, so make sure you add a new cell to try your code

# %% [markdown]
# **$\Rightarrow$
# Does the dataframe `temp` contain any missing values (NaN)?
# **
#
# Optional: if yes, how many?

# %%
# Out:
# dt                                 0
# AverageTemperature               113
# AverageTemperatureUncertainty    113
# Country                            0
# dtype: int64

# %% [markdown]
# **$\Rightarrow$
# Call the predefined function `plot_temp()` on the `temp` dataframe to see the missing values
# **

# %% [markdown]
# **$\Rightarrow$
# Impute (fill in) the missing values with 0 (zero)
# Then, call the predefined function `plot_temp()` on the `temp` dataframe to see the missing values
# **

# %% [markdown]
# **$\Rightarrow$
# Impute (fill in) the missing values with the median of average temperature (i.e. ``AverageTemperature``)
# Then, call the predefined function `plot_temp()` on the `temp` dataframe to see the missing values
# **

# %%
# Out:
# 25.91

# %% [markdown]
# **$\Rightarrow$
# Impute (fill in) the missing values with the mean of average temperature (i.e. ``AverageTemperature``)
# Then, call the predefined function `plot_temp()` on the `temp` dataframe to see the missing values
# **

# %%
# Out:
# 25.91

# %% [markdown]
# **$\Rightarrow$
# Impute (fill in) the missing values using forward-fill method `ffill`
# Then, call the predefined function `plot_temp()` on the `temp` dataframe to see the missing values
# **

# %% [markdown]
# **$\Rightarrow$
# Impute (fill in) the missing values using backward-fill method `bfill`
# Then, call the predefined function `plot_temp()` on the `temp` dataframe to see the missing values
# **

# %% [markdown]
# **$\Rightarrow$
# How many records (i.e. rows) are left after droping NAs using the method `.dropna()` on the dataframe `df` ?
# **

# %%
# Out:
#       u     v     x   y   z
# b  21.0  19.0  74.0  41  10

# %% [markdown]
# **$\Rightarrow$
# How many columns are left after droping NAs using the method `.dropna()` (with proper argument) on the dataframe `df` ?
# **

# %%
# Out:
#     y   z
# a  72   0
# b  41  10
# c  20  44
# d  26  81
# e   2  63

# %% [markdown]
# **$\Rightarrow$
# Assume that columns that contain two or more NAs are not useful, thus need to be removed.
# Use the method `.dropna()` with proper arguments to obtain the desired dataset.
# **

# %%
# Out:
#       x   y   z
# a  56.0  72   0
# b  74.0  41  10
# c  96.0  20  44
# d   NaN  26  81
# e  66.0   2  63

# %% [markdown]
# <hr>
# ## Finished !
