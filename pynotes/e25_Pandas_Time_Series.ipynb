# %% [markdown]
# # DataScience Course $\circ$ Pandas $\circ$ Time Series Data
# By Dr Boontawee Suntisrivaraporn
# <img src="https://1.bp.blogspot.com/-J1gxIX6Cp9w/Wy-lUTT-LqI/AAAAAAADIss/i8oWgsmB9OY8nRMc21XH_BA7AUCGkuGFgCLcBGAs/s1600/logo2.jpg" width=600>
# <hr>

# %% [markdown]
# ### Topics
#
# - Indexing dataframe by time
#     - Recap dataframe's index, setting index
#     - `resample()` (aggregation)
#     - `asfreq()` (selection)
#     - `shift()`, `tshift()`
#     - `rolling()` (aggregation)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

cpf = pd.read_csv("../data/CPF.BK.csv", na_values="null")
cpf.shape
# Out:
# (4611, 7)

# %% [markdown]
# ## Exercises
# - Run provided codes prior to the exercise question
# - Add a **new cell** to try your code
# - Type in Python code in the box to get the results as displayed right below
#
# __Warning__: results will be replaced, so make sure you add a new cell to try your code

# %% [markdown]
# **$\Rightarrow$
# Use `head()` and `tail()` methods to view the first and last few records records
# **
#
# Optional: use `pd.concat()` to combine the two views together into a single dataframe

# %%
# Out:
#             Date   Open   High    Low  Close  Adj Close       Volume
# 0     2000-01-04   5.54   6.02   5.54   5.81  -0.178802  151906100.0
# 1     2000-01-05   5.54   5.65   5.54   5.54  -0.170493   65416260.0
# 4609  2018-06-14  25.75  26.00  25.00  25.25  25.250000   43346700.0
# 4610  2018-06-15  25.00  25.25  24.60  25.00  25.000000   78571900.0

# %% [markdown]
# **$\Rightarrow$
# Reassign to `cpf` variable the modified dataframe by...
# **
# - changing type of "Date" to Pandas' timestamp type by using `pd.to_datetime()`
# - setting the "Date" variable as the dataframe's index
# - selecting only the "Open" column as `pd.Series`

# %%
cpf.tail(3)
# Out:
# Date
# 2018-06-13    26.00
# 2018-06-14    25.75
# 2018-06-15    25.00
# Name: Open, dtype: float64

# %% [markdown]
# **$\Rightarrow$
# Plot the time series stock prices
# **

# %% [markdown]
# **$\Rightarrow$
# Compute the moving average (i.e. rolling average) over the past 12 months to see the big pictures of the stock price trends
# **

# %% [markdown]
# **$\Rightarrow$
# NA of some data records in the dataset breaks the time series stats, incl rolling average. Fix it by first replacing NA with past known value, i.e. `method='ffill'`
# **

# %% [markdown]
# **$\Rightarrow$
# Focus the time span to year $\geq$ `2015`, set it to variable `cpf2`, and plot the time series
# **

# %% [markdown]
# **$\Rightarrow$
# On `cpf2`, compute the moving average (i.e. rolling average) over the past 1, 3, and 6 months
# **
#
# - Plot original price first using `figzie=(15, 4)`
# - Plot each rolling average separately
# - Add legend

# %% [markdown]
# ### Optional

# %% [markdown]
# <hr>
# ## Finished!
